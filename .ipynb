# %%
# !gdown "1LBpKKXFcfvUVgyk3tgQH6YxNp1KXX0Va"
# Out:
# Downloading...
# From (original): https://drive.google.com/uc?id=1LBpKKXFcfvUVgyk3tgQH6YxNp1KXX0Va
# From (redirected): https://drive.google.com/uc?id=1LBpKKXFcfvUVgyk3tgQH6YxNp1KXX0Va&confirm=t&uuid=5299059b-aa1b-4de6-9f3b-d915427fd49e
# To: e:\A yolov10\yolov10\PlantDocv4.zip
#
#   0%|          | 0.00/460M [00:00<?, ?B/s]
#   0%|          | 524k/460M [00:00<05:43, 1.34MB/s]
#   0%|          | 1.05M/460M [00:00<04:21, 1.76MB/s]
#   0%|          | 1.57M/460M [00:00<03:50, 1.99MB/s]
#   0%|          | 2.10M/460M [00:01<03:38, 2.10MB/s]
#   1%|          | 2.62M/460M [00:01<03:31, 2.17MB/s]
#   1%|          | 3.15M/460M [00:01<03:23, 2.25MB/s]
#   1%|          | 3.67M/460M [00:01<03:19, 2.29MB/s]
#   1%|          | 4.19M/460M [00:01<03:19, 2.29MB/s]
#   1%|          | 4.72M/460M [00:02<03:18, 2.29MB/s]
#   1%|          | 5.24M/460M [00:02<03:21, 2.26MB/s]
#   1%|▏         | 5.77M/460M [00:02<03:18, 2.29MB/s]
#   1%|▏         | 6.29M/460M [00:02<03:08, 2.40MB/s]
# ...

# %%
import os
import zipfile

# Create the directory
dataset_dir = "E:/A yolov10/yolov10/datasets/PlantDocv4/"
os.makedirs(dataset_dir, exist_ok=True)

# Path to the zip file
zip_path = "E:/A yolov10/yolov10/PlantDocv4.zip"

# Unzip the file
with zipfile.ZipFile(zip_path, 'r') as zip_ref:
    zip_ref.extractall(dataset_dir)

# Remove the zip file after extraction
os.remove(zip_path)

# %%
from ultralytics import YOLOv10

model = YOLOv10("E:\A yolov10\yolov10\yolov10n.pt")

# %%
model.train(data="E:\A yolov10\yolov10\datasets\PlantDocv4\data.yaml",


    epochs=10,
    imgsz=640)
# Out:
# New https://pypi.org/project/ultralytics/8.2.51 available 😃 Update with 'pip install -U ultralytics'
# Ultralytics YOLOv8.1.34 🚀 Python-3.11.5 torch-2.0.1+cpu CPU (11th Gen Intel Core(TM) i7-11800H 2.30GHz)
# ...

# %%
model = YOLOv10("E:/A yolov10\yolov10/runs/detect/train2/weights/best.pt")

model.val(data="E:\A yolov10\yolov10\datasets\PlantDocv4\data.yaml",
    imgsz=640,
    split="test")
# Out:
# Ultralytics YOLOv8.1.34 🚀 Python-3.11.5 torch-2.0.1+cpu CPU (11th Gen Intel Core(TM) i7-11800H 2.30GHz)
# YOLOv10n summary (fused): 285 layers, 2706116 parameters, 0 gradients
# val: Scanning E:\A yolov10\yolov10\datasets\PlantDocv4\test\labels... 246 images, 1 backgrounds, 0 corrupt: 100%|██████████| 246/246 [00:00<00:00, 465.33it/s]
# val: New cache created: E:\A yolov10\yolov10\datasets\PlantDocv4\test\labels.cache
#                  Class     Images  Instances      Box(P          R      mAP50  mAP50-95): 100%|██████████| 16/16 [00:37<00:00,  2.34s/it]
#                    all        246        484      0.294       0.41      0.365      0.286
#        Apple Scab Leaf        246         13      0.423      0.565      0.399      0.294
#             Apple leaf        246         10      0.277        0.6      0.403      0.332
#        Apple rust leaf        246         12      0.253      0.167      0.334      0.245
# ...
